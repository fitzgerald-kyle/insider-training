# %% [markdown]
# ## Training with a Neural Network
# This notebook contains the training of a Keras Sequential model on insider data, which attempts to predict the maximum 90-day percentage gain of a ticker whose insider(s) made a trade. We use a single dense hidden layer and a dropout layer, and we use the Keras Tuner to choose an optimal learning rate and number of hidden units.

# %%
# %load_ext autoreload
# %autoreload 1
# %aimport my_functions

import pandas as pd
import datetime as dt
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf

from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, confusion_matrix 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Dense, Dropout
from tensorflow.keras.activations import linear
from tensorflow.keras.regularizers import L2
from operator import itemgetter

from my_functions import *

pd.options.mode.chained_assignment = None
plt.style.use('fivethirtyeight')

# %%
'''
Read in the trade data and prepare it for modeling.
'''

DAYS_TO_LOOK_BACK = 6  # used for calculating volume volatility and recent-trade counts

train_and_cv = my_model_prep.prepareForModel(pd.read_csv('data/training_and_cv_data.csv'))

startDate = min(train_and_cv.FilingDate) + dt.timedelta(days=DAYS_TO_LOOK_BACK)
endDate = max(train_and_cv.FilingDate)
splitDate = startDate + dt.timedelta(days=int(0.95*(endDate-startDate).days))

train_XY, train_X, train_Y = my_model_prep.returnXandY(
    train_and_cv, dt.date.isoformat(startDate), dt.date.isoformat(splitDate), binStarts=[-10, 0, 20]
)

cv_XY, cv_X, cv_Y = my_model_prep.returnXandY(
    train_and_cv, dt.date.isoformat(splitDate+dt.timedelta(days=1)), dt.date.isoformat(endDate),
    binStarts=[-10, 0, 20]
)

# %%
print(f'Training begins on {startDate} and ends on {splitDate}')
print(f'CV begins on {splitDate+dt.timedelta(days=1)} and ends on {endDate}')
print(f'Train shape: {train_X.shape}')
print(f'CV shape: {cv_X.shape}')
# Out:
# Training begins on 2021-06-07 and ends on 2021-08-26
# CV begins on 2021-08-27 and ends on 2021-08-31
# Train shape: (23349, 10)
# CV shape: (1263, 10)

# %%
# We'll need this later.
def plotLearningCurves(history, losses):
    '''
    Plot the Keras training and cross-validation learning curves for each loss.
    
    IN:
        history (History object obtained from a Keras fit)
        losses (List[str]): contains name of each validation metric
    '''
    fig, axs = plt.subplots(1, len(losses), figsize=(6.4*len(losses), 4.8))
    if type(axs) != np.ndarray: axs = [axs]
        
    for i, name in enumerate(losses):
        trainingLoss = history.history[name]
        cvLoss = history.history['val_' + name]
        epochs = range(1, len(trainingLoss) + 1)
        
        axs[i].plot(epochs, trainingLoss, label='train')
        axs[i].plot(epochs, cvLoss, label='cv')
        axs[i].set_xlabel('Epoch')
        axs[i].set_ylabel('Loss')
        axs[i].set_title('Learning Curve: ' + name)
        axs[i].legend()

    plt.show()

# %%
'''
Perform standard feature normalization.
'''
scaler = StandardScaler().fit(train_X)
train_X_scaled = scaler.transform(train_X)
cv_X_scaled = scaler.transform(cv_X)

# %% [markdown]
# Here is a StackExchange answer that provides a starting point for deciding on the number of hidden units to include: https://stats.stackexchange.com/a/136542
#
# ### Below is a computation to obtain the absolute maximum number of hidden units:

# %%
Ns = train_X_scaled.shape[0]  # training examples
No = 1                           # output neurons
Ni = train_X_scaled.shape[1]  # input neurons
alpha = 5                # scale factor

Nh = Ns / (alpha*(Ni + No))      # maximum hidden neurons

print(f'An upper bound for number of hidden units: {int(Nh)}')
# Out:
# An upper bound for number of hidden units: 424

# %% [markdown]
# This seems like *quite* a lot; we certainly don't need this many hidden units!
#
# ### However, we can remove some of the guesswork by using Keras Tuner.
# With this tool, we can search the parameter space and also determine an optimal number of hidden units.
#
# We have 10 inputs. Let's opt for one Dense hidden layer with
# - 8 to 32 units,
# - kernel regularizer = 0.01 (to prevent weight blowup),
# - gradient clipping for norms > 1 (to prevent gradient explosion),
# - Adam optimizer with learning rate between 0.001 and 0.0001,
# - our custom loss (explained in decision_tree) for both the objective and evluation metric.

# %%
from tensorflow.python.ops import math_ops, numpy_ops
numpy_ops.np_config.enable_numpy_behavior()

def asymm_rmse(y_true, y_pred):
    '''
    A custom rmse loss function that penalizes overestimated losses by 4x and underestimated gains by 2x.
    '''
    isOverestimatedLoss = ((y_true < y_pred) & (y_true < 0)).astype(float)
    isUnderestimatedGain = ((y_true > y_pred) & (y_true > 15)).astype(float)
    
    diff = (4*isOverestimatedLoss + 2*isUnderestimatedGain + 1)*math_ops.squared_difference(y_pred, y_true)

    loss = tf.math.sqrt(tf.reduce_mean(diff, axis=-1))

    return loss

# %%
import keras_tuner as kt
from tensorflow.keras.backend import maximum, minimum

tf.random.set_seed(40)

def model_builder(numFeatures):
    def builder(tuner):
        numUnits = tuner.Int('units', min_value=8, max_value=32, step=8)
        learningRate = tuner.Choice('learningRate', values=[1e-3, 5e-4, 1e-4])
        
        clip_linear = lambda x: minimum(maximum(linear(x), -10.), 70.)
        
        model = Sequential(
            [               
                Input(shape=(numFeatures,)),
                Dense(units=numUnits, activation='relu', kernel_regularizer=L2(0.01)),
                #Dropout(0.5),
                #Dense(units=numUnits/4, activation='relu', kernel_regularizer=L2(1e-3)),
                Dense(units=1, activation=clip_linear),
            ], name = 'nn_model' 
        )

        model.compile(
            optimizer=tf.keras.optimizers.Adam(learning_rate=learningRate, clipnorm=1.0),
            loss=asymm_rmse,
            metrics=asymm_rmse
        )

        return model
    return builder

# %% [markdown]
# BayesianOptimization is an algorithm that efficiently searches the hyperparameter space.
#
# We use EarlyStopping to halt training early if there is no loss improvement in the 10 most recent epochs.

# %%
tuner = kt.BayesianOptimization(
    model_builder(train_X_scaled.shape[1]),
    objective=kt.Objective('asymm_rmse', 'min'),
    max_trials=8,
    overwrite=True,
    directory='tuner logs',
    project_name='asymm_rmse'
)

tuner.search(
    train_X_scaled, train_Y, 
    epochs=20,
    batch_size=32,
    validation_data=(cv_X_scaled, cv_Y),
    callbacks=[tf.keras.callbacks.EarlyStopping(patience=10)]
)
# Out:
# Trial 8 Complete [00h 00m 19s]
# asymm_rmse: 23.21074867248535
#
# Best asymm_rmse So Far: 23.179351806640625
# Total elapsed time: 00h 02m 30s
# INFO:tensorflow:Oracle triggered exit

# %%
best_hparams = tuner.get_best_hyperparameters()[0]

print(f'These are the best hyperparameter values: \n {best_hparams.values}')
# Out:
# These are the best hyperparameter values:
#  {'units': 32, 'learningRate': 0.0005}

# %%
'''
Let's build the model with the best parameters and use it to make predictions on the training and CV sets.
'''
nn_model = tuner.hypermodel.build(best_hparams)
history = nn_model.fit(train_X_scaled, train_Y, epochs=100, batch_size=32, validation_data=(cv_X_scaled, cv_Y))
train_Y_preds = nn_model.predict(train_X_scaled)
cv_Y_preds = nn_model.predict(cv_X_scaled)
# Out:
# Epoch 1/100
# 730/730 [==============================] - 1s 1ms/step - loss: 25.7344 - asymm_rmse: 25.6323 - val_loss: 25.7952 - val_asymm_rmse: 25.7068
# Epoch 2/100
# 730/730 [==============================] - 1s 1ms/step - loss: 25.2144 - asymm_rmse: 25.1230 - val_loss: 25.9011 - val_asymm_rmse: 25.8057
# Epoch 3/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.9345 - asymm_rmse: 24.8340 - val_loss: 25.9195 - val_asymm_rmse: 25.8142
# Epoch 4/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.7873 - asymm_rmse: 24.6769 - val_loss: 25.8099 - val_asymm_rmse: 25.6942
# Epoch 5/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.6825 - asymm_rmse: 24.5614 - val_loss: 25.6963 - val_asymm_rmse: 25.5708
# Epoch 6/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.5959 - asymm_rmse: 24.4643 - val_loss: 25.6193 - val_asymm_rmse: 25.4811
# Epoch 7/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.5149 - asymm_rmse: 24.3711 - val_loss: 25.4945 - val_asymm_rmse: 25.3444
# Epoch 8/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.4387 - asymm_rmse: 24.2834 - val_loss: 25.3823 - val_asymm_rmse: 25.2208
# Epoch 9/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.3626 - asymm_rmse: 24.1950 - val_loss: 25.3334 - val_asymm_rmse: 25.1579
# Epoch 10/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.2869 - asymm_rmse: 24.1051 - val_loss: 25.2025 - val_asymm_rmse: 25.0138
# Epoch 11/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.2103 - asymm_rmse: 24.0149 - val_loss: 25.1118 - val_asymm_rmse: 24.9092
# Epoch 12/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.1361 - asymm_rmse: 23.9266 - val_loss: 25.0275 - val_asymm_rmse: 24.8110
# Epoch 13/100
# 730/730 [==============================] - 1s 1ms/step - loss: 24.0573 - asymm_rmse: 23.8347 - val_loss: 24.9312 - val_asymm_rmse: 24.7012
# Epoch 14/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.9884 - asymm_rmse: 23.7513 - val_loss: 24.9253 - val_asymm_rmse: 24.6828
# Epoch 15/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.9261 - asymm_rmse: 23.6778 - val_loss: 24.8709 - val_asymm_rmse: 24.6164
# Epoch 16/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.8644 - asymm_rmse: 23.6053 - val_loss: 24.8002 - val_asymm_rmse: 24.5343
# Epoch 17/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.8062 - asymm_rmse: 23.5337 - val_loss: 24.6934 - val_asymm_rmse: 24.4157
# Epoch 18/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.7462 - asymm_rmse: 23.4627 - val_loss: 24.6856 - val_asymm_rmse: 24.3966
# Epoch 19/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.6905 - asymm_rmse: 23.3977 - val_loss: 24.5841 - val_asymm_rmse: 24.2863
# Epoch 20/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.6375 - asymm_rmse: 23.3344 - val_loss: 24.5639 - val_asymm_rmse: 24.2559
# Epoch 21/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.5874 - asymm_rmse: 23.2764 - val_loss: 24.4816 - val_asymm_rmse: 24.1664
# Epoch 22/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.5420 - asymm_rmse: 23.2229 - val_loss: 24.3287 - val_asymm_rmse: 24.0063
# Epoch 23/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.5046 - asymm_rmse: 23.1775 - val_loss: 24.3799 - val_asymm_rmse: 24.0485
# Epoch 24/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.4654 - asymm_rmse: 23.1319 - val_loss: 24.2273 - val_asymm_rmse: 23.8905
# Epoch 25/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.4420 - asymm_rmse: 23.1030 - val_loss: 24.1616 - val_asymm_rmse: 23.8202
# Epoch 26/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.4083 - asymm_rmse: 23.0645 - val_loss: 24.1073 - val_asymm_rmse: 23.7614
# Epoch 27/100
# 730/730 [==============================] - 1s 2ms/step - loss: 23.3831 - asymm_rmse: 23.0349 - val_loss: 24.1034 - val_asymm_rmse: 23.7527
# Epoch 28/100
# 730/730 [==============================] - 1s 2ms/step - loss: 23.3577 - asymm_rmse: 23.0047 - val_loss: 23.9320 - val_asymm_rmse: 23.5763
# Epoch 29/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.3342 - asymm_rmse: 22.9779 - val_loss: 23.9678 - val_asymm_rmse: 23.6098
# Epoch 30/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.3098 - asymm_rmse: 22.9505 - val_loss: 23.9103 - val_asymm_rmse: 23.5506
# Epoch 31/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.2934 - asymm_rmse: 22.9327 - val_loss: 23.9051 - val_asymm_rmse: 23.5435
# Epoch 32/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.2737 - asymm_rmse: 22.9115 - val_loss: 23.9510 - val_asymm_rmse: 23.5871
# Epoch 33/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.2580 - asymm_rmse: 22.8944 - val_loss: 23.8850 - val_asymm_rmse: 23.5196
# Epoch 34/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.2364 - asymm_rmse: 22.8711 - val_loss: 23.8321 - val_asymm_rmse: 23.4673
# Epoch 35/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.2217 - asymm_rmse: 22.8565 - val_loss: 23.7045 - val_asymm_rmse: 23.3406
# Epoch 36/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.2100 - asymm_rmse: 22.8452 - val_loss: 23.8409 - val_asymm_rmse: 23.4755
# Epoch 37/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1962 - asymm_rmse: 22.8313 - val_loss: 23.6790 - val_asymm_rmse: 23.3137
# Epoch 38/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1781 - asymm_rmse: 22.8125 - val_loss: 23.7924 - val_asymm_rmse: 23.4261
# Epoch 39/100
# 730/730 [==============================] - 1s 2ms/step - loss: 23.1661 - asymm_rmse: 22.8006 - val_loss: 23.6459 - val_asymm_rmse: 23.2803
# Epoch 40/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1517 - asymm_rmse: 22.7864 - val_loss: 23.7321 - val_asymm_rmse: 23.3669
# Epoch 41/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1415 - asymm_rmse: 22.7774 - val_loss: 23.7694 - val_asymm_rmse: 23.4058
# Epoch 42/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1252 - asymm_rmse: 22.7614 - val_loss: 23.7940 - val_asymm_rmse: 23.4295
# Epoch 43/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1142 - asymm_rmse: 22.7497 - val_loss: 23.7910 - val_asymm_rmse: 23.4264
# Epoch 44/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.1039 - asymm_rmse: 22.7397 - val_loss: 23.7293 - val_asymm_rmse: 23.3645
# Epoch 45/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0905 - asymm_rmse: 22.7252 - val_loss: 23.6907 - val_asymm_rmse: 23.3265
# Epoch 46/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0796 - asymm_rmse: 22.7151 - val_loss: 23.6778 - val_asymm_rmse: 23.3138
# Epoch 47/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0662 - asymm_rmse: 22.7025 - val_loss: 23.6520 - val_asymm_rmse: 23.2876
# Epoch 48/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0575 - asymm_rmse: 22.6943 - val_loss: 23.6542 - val_asymm_rmse: 23.2910
# Epoch 49/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0456 - asymm_rmse: 22.6817 - val_loss: 23.6046 - val_asymm_rmse: 23.2416
# Epoch 50/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0386 - asymm_rmse: 22.6755 - val_loss: 23.4044 - val_asymm_rmse: 23.0420
# Epoch 51/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0261 - asymm_rmse: 22.6642 - val_loss: 23.5367 - val_asymm_rmse: 23.1748
# Epoch 52/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0162 - asymm_rmse: 22.6550 - val_loss: 23.5273 - val_asymm_rmse: 23.1659
# Epoch 53/100
# 730/730 [==============================] - 1s 1ms/step - loss: 23.0072 - asymm_rmse: 22.6455 - val_loss: 23.5936 - val_asymm_rmse: 23.2319
# Epoch 54/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9982 - asymm_rmse: 22.6367 - val_loss: 23.4910 - val_asymm_rmse: 23.1312
# Epoch 55/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9921 - asymm_rmse: 22.6305 - val_loss: 23.5936 - val_asymm_rmse: 23.2324
# Epoch 56/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9847 - asymm_rmse: 22.6236 - val_loss: 23.5246 - val_asymm_rmse: 23.1641
# Epoch 57/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9726 - asymm_rmse: 22.6122 - val_loss: 23.4858 - val_asymm_rmse: 23.1246
# Epoch 58/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9641 - asymm_rmse: 22.6039 - val_loss: 23.4900 - val_asymm_rmse: 23.1304
# Epoch 59/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9574 - asymm_rmse: 22.5975 - val_loss: 23.4977 - val_asymm_rmse: 23.1385
# Epoch 60/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9465 - asymm_rmse: 22.5887 - val_loss: 23.4646 - val_asymm_rmse: 23.1067
# Epoch 61/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9427 - asymm_rmse: 22.5842 - val_loss: 23.4438 - val_asymm_rmse: 23.0851
# Epoch 62/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9312 - asymm_rmse: 22.5727 - val_loss: 23.4385 - val_asymm_rmse: 23.0806
# Epoch 63/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9229 - asymm_rmse: 22.5649 - val_loss: 23.5079 - val_asymm_rmse: 23.1500
# Epoch 64/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9198 - asymm_rmse: 22.5624 - val_loss: 23.4278 - val_asymm_rmse: 23.0699
# Epoch 65/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9149 - asymm_rmse: 22.5569 - val_loss: 23.4458 - val_asymm_rmse: 23.0890
# Epoch 66/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.9054 - asymm_rmse: 22.5491 - val_loss: 23.4258 - val_asymm_rmse: 23.0692
# Epoch 67/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8979 - asymm_rmse: 22.5415 - val_loss: 23.4302 - val_asymm_rmse: 23.0743
# Epoch 68/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8899 - asymm_rmse: 22.5344 - val_loss: 23.3762 - val_asymm_rmse: 23.0221
# Epoch 69/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8810 - asymm_rmse: 22.5263 - val_loss: 23.3782 - val_asymm_rmse: 23.0242
# Epoch 70/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8785 - asymm_rmse: 22.5249 - val_loss: 23.4474 - val_asymm_rmse: 23.0938
# Epoch 71/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8736 - asymm_rmse: 22.5206 - val_loss: 23.4062 - val_asymm_rmse: 23.0531
# Epoch 72/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8637 - asymm_rmse: 22.5114 - val_loss: 23.4557 - val_asymm_rmse: 23.1027
# Epoch 73/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8584 - asymm_rmse: 22.5062 - val_loss: 23.4839 - val_asymm_rmse: 23.1322
# Epoch 74/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8527 - asymm_rmse: 22.5011 - val_loss: 23.3658 - val_asymm_rmse: 23.0147
# Epoch 75/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8452 - asymm_rmse: 22.4946 - val_loss: 23.4242 - val_asymm_rmse: 23.0738
# Epoch 76/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8359 - asymm_rmse: 22.4857 - val_loss: 23.3954 - val_asymm_rmse: 23.0457
# Epoch 77/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8335 - asymm_rmse: 22.4832 - val_loss: 23.4470 - val_asymm_rmse: 23.0968
# Epoch 78/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8277 - asymm_rmse: 22.4779 - val_loss: 23.4845 - val_asymm_rmse: 23.1353
# Epoch 79/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8232 - asymm_rmse: 22.4746 - val_loss: 23.3579 - val_asymm_rmse: 23.0084
# Epoch 80/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8122 - asymm_rmse: 22.4633 - val_loss: 23.3960 - val_asymm_rmse: 23.0485
# Epoch 81/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8094 - asymm_rmse: 22.4622 - val_loss: 23.4387 - val_asymm_rmse: 23.0919
# Epoch 82/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.8028 - asymm_rmse: 22.4560 - val_loss: 23.4480 - val_asymm_rmse: 23.1020
# Epoch 83/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7945 - asymm_rmse: 22.4488 - val_loss: 23.5869 - val_asymm_rmse: 23.2408
# Epoch 84/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7885 - asymm_rmse: 22.4428 - val_loss: 23.3960 - val_asymm_rmse: 23.0500
# Epoch 85/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7849 - asymm_rmse: 22.4388 - val_loss: 23.4512 - val_asymm_rmse: 23.1055
# Epoch 86/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7719 - asymm_rmse: 22.4259 - val_loss: 23.3304 - val_asymm_rmse: 22.9843
# Epoch 87/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7725 - asymm_rmse: 22.4269 - val_loss: 23.3418 - val_asymm_rmse: 22.9959
# Epoch 88/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7574 - asymm_rmse: 22.4119 - val_loss: 23.2795 - val_asymm_rmse: 22.9343
# Epoch 89/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7535 - asymm_rmse: 22.4087 - val_loss: 23.3977 - val_asymm_rmse: 23.0522
# Epoch 90/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7422 - asymm_rmse: 22.3967 - val_loss: 23.4297 - val_asymm_rmse: 23.0852
# Epoch 91/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7413 - asymm_rmse: 22.3970 - val_loss: 23.3813 - val_asymm_rmse: 23.0372
# Epoch 92/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7314 - asymm_rmse: 22.3870 - val_loss: 23.3766 - val_asymm_rmse: 23.0328
# Epoch 93/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7242 - asymm_rmse: 22.3802 - val_loss: 23.3641 - val_asymm_rmse: 23.0207
# Epoch 94/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7183 - asymm_rmse: 22.3748 - val_loss: 23.3635 - val_asymm_rmse: 23.0204
# Epoch 95/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7089 - asymm_rmse: 22.3657 - val_loss: 23.2932 - val_asymm_rmse: 22.9504
# Epoch 96/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.7043 - asymm_rmse: 22.3611 - val_loss: 23.3785 - val_asymm_rmse: 23.0355
# Epoch 97/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.6974 - asymm_rmse: 22.3551 - val_loss: 23.2720 - val_asymm_rmse: 22.9300
# Epoch 98/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.6843 - asymm_rmse: 22.3429 - val_loss: 23.2574 - val_asymm_rmse: 22.9151
# Epoch 99/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.6785 - asymm_rmse: 22.3361 - val_loss: 23.2978 - val_asymm_rmse: 22.9570
# Epoch 100/100
# 730/730 [==============================] - 1s 1ms/step - loss: 22.6744 - asymm_rmse: 22.3335 - val_loss: 23.3427 - val_asymm_rmse: 23.0025
# 730/730 [==============================] - 1s 822us/step
# 40/40 [==============================] - 0s 1ms/step

# %%
plotLearningCurves(history, ['asymm_rmse'])

# %% [markdown]
# Our algorithm more-or-less stops improving on the CV set after ~20 epochs, even though it's not done learning after 60 epochs.

# %%
my_plots.plotPredictedVsActual(train_Y_preds, train_Y, cv_Y_preds, cv_Y)

# %% [markdown]
# Training on the left; CV on the right.
#
# Training leaves A LOT to be desired. There is a significant number of overestimated losses, and tons of high-gainers that are predicted to be losses. It's honestly surprising that the CV data is predicted decently well -- it likely helps that there weren't as many significant losses during this time period.

# %%
my_plots.confusionMatrix(cv_Y_preds, cv_Y.to_numpy(), benchmark=5, maxCatVal=350)

# %% [markdown]
# ### Plotted this way, we see our model's strength.
#
# It is actually relatively similar to the XGBoost output, but we're "better" at identifying losses (in that, at least, we predict many more to go 0-5% rather than 5-15%).
#
# Perhaps we can place decent trust in our model's high predictions in order to create a good strategy in strategy_simulation!

# %%
nn_model.save('models/nn_model')
# Out:
# INFO:tensorflow:Assets written to: models/nn_model\assets

# %%
cv_XY_saved = my_misc.load_obj('data/cv_XY')
cv_XY_saved['NN_Prediction'] = cv_Y_preds
my_misc.save_obj(cv_XY_saved, 'data/cv_XY')
