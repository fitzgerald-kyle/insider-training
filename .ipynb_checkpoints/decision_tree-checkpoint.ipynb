# %%
import pandas as pd
import os
import datetime
import numpy as np
from sklearn import tree
from sklearn import preprocessing
from sklearn import metrics
from sklearn.tree import export_graphviz 
from sklearn.model_selection import GridSearchCV
from chefboost import Chefboost as chef
import matplotlib.pyplot as plt

# %%
insiderDat = pd.read_csv('data/training_data.csv')
insiderDat.head()
# Out:
#    Unnamed: 0    X           FilingDate            TradeDate Ticker  \
# 0           0  NaN  2021-06-11 18:00:00  2021-06-11 00:00:00    IBP
# 1           1  NaN  2021-06-11 19:21:00  2021-06-11 00:00:00    DXC
# 2           2  NaN  2021-06-11 16:50:00  2021-06-11 00:00:00   REVG
# 3           3  NaN  2021-06-11 19:43:00  2021-06-11 00:00:00   AMST
# 4           4  NaN  2021-06-11 19:47:00  2021-06-11 00:00:00   TLYS
#
#                          CompanyName            InsiderName Title  \
# 0  Installed Building Products, Inc.       Thomas Michael H   Dir
# 1                  Dxc Technology Co       Fernandez Raul J   Dir
# 2                    Rev Group, Inc.  Boettinger Stephen W.    GC
# 3                       Amesite Inc.       Sastry Ann Marie   CEO
# 4                      Tilly'S, Inc.       Zeichner Bernard   Dir
#
#       TradeType   Price  ...  1d  1w  1m  6m         ref  10%  50%  100%  \
# 0      S - Sale  116.85  ... NaN NaN NaN NaN  119.379997  0.0  0.0   0.0
# ...

# %%
# important people: 'Dir', 'EVP, Dir. Corp. Development', 'SVP Operations', 'Executive Vice President', 'EVP',
# 'EVP, Dir OF REG RISK MNGT', 'SR EVP OF SPECIAL PROJECTS',  'VP Finance, Accounting', 'V.P. Ind. Relations & Safety', 
#  'VP, Finance', 'SVP',  'VP, Controller', 'Pres of Millis Transfer', 'EVP, HR'

# 'C-suite': 'CEO', 'Pres, CEO ASRV Bank', 'Chief Commercial Officer', 'CHRO', 'CFO', 'Chief Administration Officer', 
# 'COB, Pres, CEO', 'Chief Medical Officer', 'Pres, CEO', 'EVP & CFO', 'President & CEO', 'CEO, TSC Bank, Dir TSC', 'SVP, CFO',
# 'Chief Strategy Officer', 'SVP, CFO, Treasurer', 'EVP, COO', 'CEO, Pres', 'Pres, COO', 'COO', 'Pres', 'VP, CTO', 'EVP, CFO',
# 'EVP, CHIEF RISK OFFICER', 'CHIEF INNOVATION OFFICER', 'VP, Interim CFO, Sec., Treas.',  'Chief Business Officer', 'COB',
#  'COB, CEO, Pres', 'Chief Scientific Officer', 'CFO, Secretary, Treasurer', 'Exec COB', 'Chief Business - Strategy Off',
#  'Chief Accounting Officer', 

# Other: 'GC', 'GC, Secretary', 'Controller', 'See Remarks', 'SVP, GC', 'Corporate Secretary'
# majority stakeholders: '10%', 'CFO, 10%', 'Dir, 10%', 'CEO, 10%', 'Possible Member of 10% Group, 10%','Pres, CEO, 10%', 
# 'COB, Pres, 10%', 'COB, CEO, 10%', 'Acting CFO, 10%', 'CEO, COB, 10%'

# %%
insiderDat.InsiderName = insiderDat.InsiderName.str.replace("'", " ", regex=True) #names like O'Brien

def fix_title(r):
    if r in ['Dir', 'EVP, Dir. Corp. Development', 'SVP Operations', 'Executive Vice President', 'EVP',
 'EVP, Dir OF REG RISK MNGT', 'SR EVP OF SPECIAL PROJECTS',  'VP Finance, Accounting', 'V.P. Ind. Relations & Safety',
 'VP, Finance', 'SVP',  'VP, Controller', 'Pres of Millis Transfer', 'EVP, HR']:
        newr = 'VP and Dirs'
    elif r in [ 'CEO', 'Pres, CEO ASRV Bank', 'Chief Commercial Officer', 'CHRO', 'CFO', 'Chief Administration Officer', 
 'COB, Pres, CEO', 'Chief Medical Officer', 'Pres, CEO', 'EVP & CFO', 'President & CEO', 'CEO, TSC Bank, Dir TSC', 'SVP, CFO',
 'Chief Strategy Officer', 'SVP, CFO, Treasurer', 'EVP, COO', 'CEO, Pres', 'Pres, COO', 'COO', 'Pres', 'VP, CTO', 'EVP, CFO',
 'EVP, CHIEF RISK OFFICER', 'CHIEF INNOVATION OFFICER', 'VP, Interim CFO, Sec., Treas.',  'Chief Business Officer', 'COB',
  'COB, CEO, Pres', 'Chief Scientific Officer', 'CFO, Secretary, Treasurer', 'Exec COB', 'Chief Business - Strategy Off',
  'Chief Accounting Officer']:
        newr = 'C-suite'
    elif r in ['10%', 'CFO, 10%', 'Dir, 10%', 'CEO, 10%', 'Possible Member of 10% Group, 10%','Pres, CEO, 10%', 
 'COB, Pres, 10%', 'COB, CEO, 10%', 'Acting CFO, 10%', 'CEO, COB, 10%']:
        newr = 'Club of 10%'
    else:
        newr = 'Other'
    return newr

insiderDat.Title = [fix_title(r) for r in insiderDat.Title]

# %% [markdown]
# ## Chefboost

# %%
# # splitting dataset into a training and testing dataset based on date
# delta_train = datetime.datetime.strptime('2021-06-19', '%Y-%m-%d') - datetime.datetime.strptime('2021-06-01', '%Y-%m-%d')

# train_days = []
# for i in range(delta_train.days + 1):
#     train_days.append(datetime.datetime.strptime('2021-06-01', '%Y-%m-%d') + datetime.timedelta(days=i))

# delta_test = datetime.datetime.strptime('2021-06-30', '%Y-%m-%d') - datetime.datetime.strptime('2021-06-20', '%Y-%m-%d')

# test_days = []
# for i in range(delta_test.days + 1):
#     test_days.append(datetime.datetime.strptime('2021-06-20', '%Y-%m-%d') + datetime.timedelta(days=i))

# insiderDat.TradeDate = [datetime.datetime.strptime(d, '%Y-%m-%d %H:%M:%S') for d in insiderDat.TradeDate]
# insiderDat_purchases = insiderDat[insiderDat.TradeType == 'P - Purchase'] #only interested in purchases
# insiderDat_purchases.drop(columns=['TradeType','CompanyName','Unnamed: 0', 'X', 'FilingDate', '1d', '1w', '1m', '6m', 'ref'], 
#                           inplace=True)

# # Making training and testing sets
# training_data_XY = insiderDat_purchases[insiderDat_purchases['TradeDate'].isin(train_days)]
# training_data = training_data_XY.drop(columns=['TradeDate', 'Ticker', '10%', '50%', '100%', 'perChange', 'InsiderName'])
# training_data = training_data.join(training_data_XY['perChange'])
# training_data.rename(columns={'perChange':"Decision"}, inplace=True)

# testing_data_XY = insiderDat_purchases[insiderDat_purchases['TradeDate'].isin(test_days)]
# testing_data = testing_data_XY.drop(columns=['TradeDate', 'Ticker','10%', '50%', '100%', 'perChange', 'InsiderName'])
# testing_data = testing_data.join(testing_data_XY['perChange'])
# testing_data.rename(columns={'perChange':"Decision"}, inplace=True)

# %%
# config = {'algorithm': 'Regression'}
# model = chef.fit(training_data, config = config)
# #prediction = chef.predict(model, X_test.iloc[0])
# evaluation = chef.evaluate(model, testing_data, task="test")


# rules = "outputs/rules/rules.py"
# fi = chef.feature_importance(rules).set_index("feature")
# fi.plot(kind="barh", title="Feature Importance");

# %% [markdown]
# ## sklearn continuous outcome

# %%
delta_train = datetime.datetime.strptime('2021-06-19', '%Y-%m-%d') - datetime.datetime.strptime('2021-06-01', '%Y-%m-%d')

train_days = []
for i in range(delta_train.days + 1):
    train_days.append(datetime.datetime.strptime('2021-06-01', '%Y-%m-%d') + datetime.timedelta(days=i))

delta_test = datetime.datetime.strptime('2021-06-30', '%Y-%m-%d') - datetime.datetime.strptime('2021-06-20', '%Y-%m-%d')

test_days = []
for i in range(delta_test.days + 1):
    test_days.append(datetime.datetime.strptime('2021-06-20', '%Y-%m-%d') + datetime.timedelta(days=i))

insiderDat.TradeDate = [datetime.datetime.strptime(d, '%Y-%m-%d %H:%M:%S') for d in insiderDat.TradeDate]
insiderDat_purchases = insiderDat[insiderDat.TradeType == 'P - Purchase'] #only interested in purchases
insiderDat_purchases.drop(columns=['TradeType','CompanyName','Unnamed: 0', 'X', 'FilingDate', '1d', '1w', '1m', '6m', 'ref', 
                                   'changeCat'], 
                          inplace=True)
# Out:
# C:\Users\cdelannoy\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
# Making training and testing sets
filtered_data = insiderDat_purchases.drop(columns=['Ticker', '10%', '50%', '100%', 'InsiderName'])
dummies_data = pd.get_dummies(filtered_data, columns=["Title"], prefix=["Title_"])

training_data_XY = dummies_data[dummies_data['TradeDate'].isin(train_days)]
training_data_XY.dropna(inplace=True)
training_data_X = training_data_XY.drop(columns=['perChange', 'TradeDate'])
training_Y = training_data_XY['perChange']

assert np.any(np.isnan(training_data_X)) == False
assert np.all(np.isfinite(training_data_X)) == True
assert np.any(np.isnan(training_Y)) == False
assert np.all(np.isfinite(training_Y)) == True

testing_data_XY = dummies_data[dummies_data['TradeDate'].isin(test_days)]
testing_data_XY.dropna(inplace=True)
testing_data_X = testing_data_XY.drop(columns=['perChange', 'TradeDate'])
testing_Y = testing_data_XY['perChange']

assert np.any(np.isnan(testing_data_X)) == False
assert np.all(np.isfinite(testing_data_X)) == True
assert np.any(np.isnan(testing_Y)) == False
assert np.all(np.isfinite(testing_Y)) == True
# Out:
# C:\Users\cdelannoy\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
training_data_X.head()
# Out:
#    Price      Qty      Owned  DeltaOwn     Value  Title__C-suite  \
# 1  41.20   1820.0    31305.0       6.0   74975.0               0
# 2  15.64   1500.0   121560.0       1.0   23460.0               0
# 3   3.73  15000.0  6241667.0       0.0   55950.0               1
# 5  15.87  19292.0   968287.0       2.0  306164.0               1
# 6   1.14  18180.0   468831.0       4.0   20725.0               1
#
#    Title__Club of 10%  Title__Other  Title__VP and Dirs
# 1                   0             0                   1
# 2                   0             1                   0
# 3                   0             0                   0
# 5                   0             0                   0
# 6                   0             0                   0

# %%
skr_parameters = [{
'max_depth': [3, 5, 10, None], 
'min_samples_split': [2, 5, 10],
'min_samples_leaf': [1, 5, 10]}]

dtr = GridSearchCV(
        tree.DecisionTreeRegressor(), skr_parameters
    )
dtr.fit(training_data_X, training_Y)
print(dtr.best_params_)
# Out:
# {'max_depth': 5, 'min_samples_leaf': 10, 'min_samples_split': 2}

# %%
skr = tree.DecisionTreeRegressor(max_depth= 5, min_samples_leaf= 10, min_samples_split= 2)
skr = skr.fit(training_data_X, training_Y)

# %%
preds = skr.predict(testing_data_X)
metrics.mean_squared_error(testing_Y, preds)
# Out:
# 0.08349447189456409

# %%
# export the decision tree to a tree.dot file
# for visualizing the plot easily anywhere
export_graphviz(skr, out_file ='tree.dot',
               feature_names = training_data_X.columns)

# %%
skr_importances = pd.Series(skr.feature_importances_, index=training_data_X.columns)

fig, ax = plt.subplots()
skr_importances.plot.bar()
ax.set_title("Feature importances using Regression tree")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(skr, feature_names=training_data_X.columns, rounded=True, filled=True)
fig.savefig("regression_tree.png")

# %% [markdown]
# ## Strategy

# %%
full_test_dat_preds = testing_data_XY.copy()
full_test_dat_preds['preds'] = preds
full_test_dat_preds.head()
# Out:
#       TradeDate  Price       Qty      Owned  DeltaOwn      Value  perChange  \
# 994  2021-06-30  12.94    1800.0     1800.0   99999.0    23297.0   0.140671
# 995  2021-06-30  12.66     500.0   385575.0       0.0     6330.0   0.140671
# 1001 2021-06-29  12.09  809039.0  4618468.0      21.0  9781137.0   0.156881
# 1003 2021-06-29   5.35    1000.0    11137.0      10.0     5345.0   0.304264
# 1004 2021-06-29   5.31    1000.0   190842.0       1.0     5310.0   0.304264
#
#       Title__C-suite  Title__Club of 10%  Title__Other  Title__VP and Dirs  \
# 994                0                   0             0                   1
# 995                1                   0             0                   0
# 1001               0                   1             0                   0
# 1003               1                   0             0                   0
# 1004               1                   0             0                   0
#
#          preds
# 994   0.222004
# 995   0.144876
# ...

# %%
def build_flag(r):
    if r >= 0.20 and r < 0.50:
        return 'between 20 and 50%'
    elif r >= 0.50 and r < 1:
        return 'between 50% and 100%'
    elif r >= 1:
        return 'at least 100%'
    else:
        return 'not enough'

full_test_dat_preds['flag'] = [build_flag(r) for r in full_test_dat_preds.preds]
full_test_dat_preds['flag'].value_counts()
# Out:
# not enough              41
# between 20 and 50%      16
# at least 100%            3
# between 50% and 100%     2
# Name: flag, dtype: int64

# %%
TickerDat = pd.read_pickle('data/tickerDat_fmt.pkl')

# %% [markdown]
# ### Strategy: at least 20%
#
# Constraints: buy stock one day after TradeDate to allow for filing time (usually same day)

# %%
purs_to_mimick_20 = full_test_dat_preds.copy()
purs_to_mimick_20 = purs_to_mimick_20[purs_to_mimick_20['flag'] != 'not enough']
purs_to_mimick_20['Pur_day'] = [t + datetime.timedelta(days=1) for t in purs_to_mimick_20.TradeDate]
purs_to_mimick_20 = purs_to_mimick_20.join(insiderDat_purchases['Ticker'])
purs_to_mimick_20['weekday'] = [d.weekday() for d in purs_to_mimick_20.Pur_day]
purs_to_mimick_20['weekday'].value_counts() # can't be 5 (Sat) or 6 (Sund)

# %%
def find_value(i):
    try:
        t = TickerDat[purs_to_mimick_20['Ticker'][i]][TickerDat[purs_to_mimick_20['Ticker'][i]].index == purs_to_mimick_20['Pur_day'][i]]['Open'][0]
        return t
    except:
        print('Didn t work for these indices: {}'.format(i))
        
purs_to_mimick_20['stockPrice_pur'] = [find_value(i) for i in purs_to_mimick_20.index]
# Out:
# Didn t work for these indices: 1001
# Didn t work for these indices: 1036
# Didn t work for these indices: 1041
# Didn t work for these indices: 1043

# %%
purs_to_mimick_20['stockPrice_pur'][1001] = TickerDat['FTCV'][TickerDat['FTCV'].index == '2021-07-01']['Open'][0]
purs_to_mimick_20['stockPrice_pur'][1036] = TickerDat['WWR'][TickerDat['WWR'].index == '2021-07-01']['Open'][0]
purs_to_mimick_20['stockPrice_pur'][1041] = TickerDat['VINC'][TickerDat['VINC'].index == '2021-07-01']['Open'][0]
purs_to_mimick_20['stockPrice_pur'][1043] = TickerDat['VINC'][TickerDat['VINC'].index == '2021-07-01']['Open'][0]
# Out:
# C:\Users\CDELAN~1\AppData\Local\Temp/ipykernel_11940/1858771217.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purs_to_mimick_20['stockPrice_pur'][1001] = TickerDat['FTCV'][TickerDat['FTCV'].index == '2021-07-01']['Open'][0]
# C:\Users\CDELAN~1\AppData\Local\Temp/ipykernel_11940/1858771217.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   purs_to_mimick_20['stockPrice_pur'][1036] = TickerDat['WWR'][TickerDat['WWR'].index == '2021-07-01']['Open'][0]
# C:\Users\CDELAN~1\AppData\Local\Temp/ipykernel_11940/1858771217.py:3: SettingWithCopyWarning:
# ...

# %%
# building portfolio -- buying 5 of each stock (what's important is % change anyways)
purs_to_mimick_20['pur_value'] = [p*5 for p in purs_to_mimick_20.stockPrice_pur]
sum(purs_to_mimick_20['pur_value']) #how much did we spend?
# Out:
# 1303.7275045365095

# %%
# selling when value hits at least +20% over next month
def sale_price(i): #index of purs df
    price_to_beat = purs_to_mimick_20['stockPrice_pur'][i]*1.20 # increase of 20%
    tDat = TickerDat[purs_to_mimick_20['Ticker'][i]]
    tDat_flt = tDat[tDat.index > purs_to_mimick_20['Pur_day'][i]]
    tDat_flt_p = tDat_flt[tDat_flt['Open'] > price_to_beat]
    try:
        return [tDat_flt_p['Open'].iloc[0], tDat_flt_p.index[0]]
    except:
        print('These tickers don t get over 20% change: {}'.format(purs_to_mimick_20['Ticker'][i]))
        return [tDat['Open'].iloc[-1], tDat.index[-1]] # selling them at the end of our 3 months timeline

sales_dat = pd.DataFrame([sale_price(i) for i in purs_to_mimick_20.index], columns=['sale_price', 'sale_date'])
purs_to_mimick_20['sale_price'] = np.array(sales_dat.sale_price)
purs_to_mimick_20['sale_date'] = np.array(sales_dat.sale_date)
# Out:
# These tickers don t get over 20% change: FTCV
# These tickers don t get over 20% change: WWR
# These tickers don t get over 20% change: GLTO
# These tickers don t get over 20% change: TRVN
# These tickers don t get over 20% change: SREV
# These tickers don t get over 20% change: FTCV
# These tickers don t get over 20% change: BFIN
# These tickers don t get over 20% change: PCSA
# These tickers don t get over 20% change: RMBL
# These tickers don t get over 20% change: TPTX

# %%
purs_to_mimick_20['sale_value'] = purs_to_mimick_20.sale_price*5 #number of stocks we bought
total_per_change = (sum(purs_to_mimick_20.pur_value) - sum(purs_to_mimick_20.sale_value))/sum(purs_to_mimick_20.pur_value)
total_per_change*100
# Out:
# 11.510304007673009

# %% [markdown]
# ## Strategy: between 50% and 100%

# %%
purs_to_mimick_50 = full_test_dat_preds.copy()
purs_to_mimick_50 = purs_to_mimick_50[(purs_to_mimick_50['flag']  == 'between 50% and 100%') | (purs_to_mimick_50['flag'] == 'at least 100%')]
purs_to_mimick_50['Pur_day'] = [t + datetime.timedelta(days=1) for t in purs_to_mimick_50.TradeDate]
purs_to_mimick_50 = purs_to_mimick_50.join(insiderDat_purchases['Ticker'])
purs_to_mimick_50['weekday'] = [d.weekday() for d in purs_to_mimick_50.Pur_day]
purs_to_mimick_50['weekday'].value_counts() # can't be 5 (Sat) or 6 (Sund)
# Out:
# 1    4
# 2    1
# Name: weekday, dtype: int64

# %%
purs_to_mimick_50['stockPrice_pur'] = [find_value(i) for i in purs_to_mimick_50.index]
# building portfolio -- buying 200 of each stock (what's important is % change anyways)
purs_to_mimick_50['pur_value'] = [p*200 for p in purs_to_mimick_50.stockPrice_pur]
sum(purs_to_mimick_50['pur_value']) #how much did we spend?
# Out:
# 886.4999920129776

# %%
# selling when value hits at least +20% over next month
def sale_price_50(i): #index of purs df
    price_to_beat = purs_to_mimick_50['stockPrice_pur'][i]*1.50 # increase of 50%
    tDat = TickerDat[purs_to_mimick_50['Ticker'][i]]
    tDat_flt = tDat[tDat.index > purs_to_mimick_50['Pur_day'][i]]
    tDat_flt_p = tDat_flt[tDat_flt['Open'] > price_to_beat]
    try:
        return [tDat_flt_p['Open'].iloc[0], tDat_flt_p.index[0]]
    except:
        print('These tickers don t get over 50% change: {}'.format(purs_to_mimick_50['Ticker'][i]))
        return [tDat['Open'].iloc[-1], tDat.index[-1]] # selling them at the end of our 3 months timeline
    
sales_dat = pd.DataFrame([sale_price_50(i) for i in purs_to_mimick_50.index], columns=['sale_price', 'sale_date'])
purs_to_mimick_50['sale_price'] = np.array(sales_dat.sale_price)
purs_to_mimick_50['sale_date'] = np.array(sales_dat.sale_date)
purs_to_mimick_50['sale_value'] = purs_to_mimick_50.sale_price*200 #number of stocks we bought
total_per_change = (sum(purs_to_mimick_50.pur_value) - sum(purs_to_mimick_50.sale_value))/sum(purs_to_mimick_50.pur_value)
total_per_change*100
# Out:
# These tickers don t get over 50% change: TRVN
# These tickers don t get over 50% change: FRXX
# These tickers don t get over 50% change: SREV
# These tickers don t get over 50% change: SEAC
# 38.40722026595106

# %% [markdown]
# ## Strategy: at least 100%

# %%
purs_to_mimick_100 = full_test_dat_preds.copy()
purs_to_mimick_100 = purs_to_mimick_100[(purs_to_mimick_100['flag']  == 'at least 100%')]
purs_to_mimick_100['Pur_day'] = [t + datetime.timedelta(days=1) for t in purs_to_mimick_100.TradeDate]
purs_to_mimick_100 = purs_to_mimick_100.join(insiderDat_purchases['Ticker'])
purs_to_mimick_100['weekday'] = [d.weekday() for d in purs_to_mimick_100.Pur_day]
purs_to_mimick_100['weekday'].value_counts() # can't be 5 (Sat) or 6 (Sund)
# Out:
# 1    3
# Name: weekday, dtype: int64

# %%
purs_to_mimick_100['stockPrice_pur'] = [find_value(i) for i in purs_to_mimick_100.index]
# building portfolio -- buying 200 of each stock (what's important is % change anyways)
purs_to_mimick_100['pur_value'] = [p*200 for p in purs_to_mimick_100.stockPrice_pur]
sum(purs_to_mimick_100['pur_value']) #how much did we spend?
# Out:
# 853.3999919891357

# %%
# selling when value hits at least +20% over next month
def sale_price_100(i): #index of purs df
    price_to_beat = purs_to_mimick_100['stockPrice_pur'][i]*2 # increase of 100%
    tDat = TickerDat[purs_to_mimick_100['Ticker'][i]]
    tDat_flt = tDat[tDat.index > purs_to_mimick_100['Pur_day'][i]]
    tDat_flt_p = tDat_flt[tDat_flt['Open'] > price_to_beat]
    try:
        return [tDat_flt_p['Open'].iloc[0], tDat_flt_p.index[0]]
    except:
        print('These tickers don t get over 100% change: {}'.format(purs_to_mimick_100['Ticker'][i]))
        return [tDat['Open'].iloc[-1], tDat.index[-1]] # selling them at the end of our 5 months timeline
    
sales_dat = pd.DataFrame([sale_price_100(i) for i in purs_to_mimick_100.index], columns=['sale_price', 'sale_date'])
purs_to_mimick_100['sale_price'] = np.array(sales_dat.sale_price)
purs_to_mimick_100['sale_date'] = np.array(sales_dat.sale_date)
purs_to_mimick_100['sale_value'] = purs_to_mimick_100.sale_price*200 #number of stocks we bought
total_per_change = (sum(purs_to_mimick_100.pur_value) - sum(purs_to_mimick_100.sale_value))/sum(purs_to_mimick_100.pur_value)
total_per_change*100
# Out:
# These tickers don t get over 100% change: TRVN
# These tickers don t get over 100% change: SREV
# These tickers don t get over 100% change: SEAC
# 38.36419122768248
